# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
file = pd.read_excel('bikedata.xlsx')

# %%
file
# Out:
#          ID Marital Status Gender  Income  Children            Education  \
# 0     12496              M      F   40000         1            Bachelors
# 1     24107              M      M   30000         3      Partial College
# 2     14177              M      M   80000         5      Partial College
# 3     24381              S      M   70000         0            Bachelors
# 4     25597              S      M   30000         0            Bachelors
# ...     ...            ...    ...     ...       ...                  ...
# 1021  16466              S      F   20000         0  Partial High School
# 1022  19273              M      F   20000         2      Partial College
# 1023  22400              M      M   10000         0      Partial College
# 1024  20942              S      F   20000         0          High School
# 1025  18484              S      M   80000         2          High School
#
#           Occupation Home Owner  Cars Commute Distance   Region  Age  \
# ...

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# Removing Duplicate

# %%
file.drop_duplicates(inplace = True)

# %%
file
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
#Replacing 'M' & 'S' with 'Married' & 'Single' respectively

file['Marital Status']=file['Marital Status'].replace(['M','S'],['Married','Single'])

# %%
file
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496        Married      F   40000         1        Bachelors
# 1    24107        Married      M   30000         3  Partial College
# 2    14177        Married      M   80000         5  Partial College
# 3    24381         Single      M   70000         0        Bachelors
# 4    25597         Single      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731        Married      M   60000         2      High School
# 996  28672         Single      M   70000         4  Graduate Degree
# 997  11809        Married      M   60000         2        Bachelors
# 998  19664         Single      M  100000         3        Bachelors
# 999  12121         Single      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
#Replacing 'M' & 'F' with 'Male' & 'Female' respectively

file['Gender']=file['Gender'].replace(['M','F'],['Male','Female'])
file
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %%
#Grouping the ages in different age brackets

def age_grouping(age):
    if age<=30:
        return 'Adolescent'
    elif age<=54:
        return 'Middle Age'
    else:
        return 'old'
    
file['Age Bracket']=file['Age'].apply(age_grouping)

# %%
file
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %% [markdown]
# ### Showing relationships using Pivot table

# %%
#Relationship between average income of each gender and their bike purchase history

piv1 = np.round(file.pivot_table (index= 'Gender',
                       columns= 'Purchased Bike',
                       values= 'Income',
                       aggfunc= 'mean'),0)
piv1
# Out:
# Purchased Bike       No      Yes
# Gender
# Female          53440.0  55774.0
# Male            56208.0  60124.0

# %%
#Relationship between distance travelled by cummuters and bike purchase

piv2= np.round(file.pivot_table (index= 'Commute Distance',
                                 values= 'Purchased Bike',
                                 aggfunc= 'count'),0)
piv2
# Out:
#                   Purchased Bike
# Commute Distance
# 0-1 Miles                    366
# 1-2 Miles                    169
# 10+ Miles                    111
# 2-5 Miles                    162
# 5-10 Miles                   192

# %%
#Relationship between age bracket and bike purchase

piv3= np.round(file.pivot_table(index= 'Age Bracket',
                      values= 'Purchased Bike',
                      aggfunc= 'count'),0)
piv3
# Out:
#              Purchased Bike
# Age Bracket
# Adolescent              110
# Middle Age              701
# old                     189

# %%
#For Pivot table 1

piv1.plot(kind='bar', figsize=(8,5))
plt.title('Average Income by Gender and Bike Purchase')
plt.xlabel('Purchased Bike')
plt.ylabel('Average Income')
# Out:
# Text(0, 0.5, 'Average Income')

# %%
#For Pivot table 2

piv2.plot(kind='line', figsize=(8,5))
plt.title('Bike Purchase by Commute Distance')
plt.xlabel('Commute Distance')
plt.ylabel('Bike Purchase')
# Out:
# Text(0, 0.5, 'Bike Purchase')

# %%
#For Pivot table 3

piv3.plot(kind='bar', figsize=(8,5))
plt.title('Bike Purchases by Age Bracket')
plt.xlabel('Age Bracket')
plt.ylabel('Bike Purchases')
# Out:
# Text(0, 0.5, 'Bike Purchases')
